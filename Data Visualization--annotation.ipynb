# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as style
style.use('seaborn-paper')
# Make a fake dataset
height = [3, 12, 5, 18, 45]
bars = ['A', 'B', 'C', 'D', 'E']
y_pos = np.arange(len(bars))

## change order
orders = np.array(height).argsort()[::-1]
height = np.array(height)[orders]
bars = np.array(bars)[orders]
bars

barplot = plt.bar(y_pos, height, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='grey')
barplot[0].set_color('darkred')
plt.xticks(y_pos, bars)
plt.xlabel('Sample plots', fontsize = 15, weight = 'bold')
plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
#from colorspacious import cspace_converter
from collections import OrderedDict

cmaps = OrderedDict()

cmaps['Perceptually Uniform Sequential'] = [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']

cmaps['Sequential'] = [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
cmaps['Qualitative'] = ['Pastel1', 'Pastel2', 'Paired', 'Accent',
                        'Dark2', 'Set1', 'Set2', 'Set3',
                        'tab10', 'tab20', 'tab20b', 'tab20c']

nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps.items())
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps.items():
    plot_color_gradients(cmap_category, cmap_list, nrows)

plt.show()

# %% [markdown]
# ### Display number, shade some colors, change ylim

# %%
cls = ['grey' if x == max(height) else "red" for x in height]
ax = sns.barplot(bars,height,palette=cls)
sns.set_context('paper')
for i in range(len(height)):
    ax.text(i, height[i], height[i], va='bottom', ha='center', fontsize=12,color='black',weight = 'bold')

    
## change ylim
ax.set_ylim((ax.get_ylim()[0],ax.get_ylim()[1]+1))
# Out:
# C:\Users\xiaoxuanliu\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (0.0, 48.25)

# %%
# Out:
# 47.75

# %% [markdown]
# #### Another way using grouped data -- using groupedvalue.iterrows():

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = sns.load_dataset("tips")
groupedvalues=df.groupby('day').sum().reset_index()

pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["total_bill"].argsort().argsort() 
g=sns.barplot(x='day',y='tip',data=groupedvalues, palette=np.array(pal[::-1])[rank])

for index, row in groupedvalues.iterrows():
    #print(row)
    g.text(row.name,row.tip, round(row.total_bill,2), color='black', ha="center")

plt.show()

# %%
cls = ['grey' if x == max(height) else "red" for x in height]
ax = sns.barplot(bars,height,palette='rocket')
sns.set_context('paper')
# Out:
# C:\Users\xiaoxuanliu\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Height one line in spaghetti plot

# %%
import pandas as pd
df = pd.DataFrame({'x':range(1,11),'y1':np.random.randn(10),'y2':np.random.randn(10)+range(1,11),'y3':
                  np.random.randn(10)+range(11,21),'y4':np.random.randn(10)+range(6,16),'y5':np.random.randn(10)+range(4,14)+np.random.normal(10),
                  'y6':np.random.randn(10)+range(2,12),'y7':np.random.randn(10)+range(5,15),'y8':np.random.randn(10)+range(4,14)})
style.use('seaborn-darkgrid')
my_dpi=96
plt.plot(figsize = (480/my_dpi, 480/my_dpi),dpi=my_dpi)
### multiple line plot

for column in df.columns[1:]:
    plt.plot(df[column],color = 'grey',marker = '',linewidth = 1,alpha=0.4)

plt.plot(df['y6'],marker = '*',color='orange',linewidth=4,alpha=0.7)
## add annotation

num = 0
for i in df.columns[1:]:
    num+=1
    if i !='y6':
        plt.text(9.2, df[i][9], i, ha='left',size='small',color='red')


plt.text(8,df['y6'][9], 'my color',size='large')
# Out:
# Text(8, 11.392820874298504, 'my color')

# %% [markdown]
# ### Stacked Bar chart

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# Data
r = [0,1,2,3,4]
raw_data = {'greenBars': [20, 1.5, 7, 10, 5], 'orangeBars': [5, 15, 5, 10, 15],'blueBars': [2, 15, 18, 5, 10]}
df = pd.DataFrame(raw_data)
 
# From raw value to percentage
totals = [i+j+k for i,j,k in zip(df['greenBars'], df['orangeBars'], df['blueBars'])]
greenBars = [i / j * 100 for i,j in zip(df['greenBars'], totals)]
orangeBars = [i / j * 100 for i,j in zip(df['orangeBars'], totals)]
blueBars = [i / j * 100 for i,j in zip(df['blueBars'], totals)]
 
# plot
barWidth = 0.85
names = ('A','B','C','D','E')
# Create green Bars
plt.bar(r, greenBars, color='#b5ffb9', edgecolor='white', width=barWidth)
# Create orange Bars
plt.bar(r, orangeBars, bottom=greenBars, color='#f9bc86', edgecolor='white', width=barWidth)
# Create blue Bars
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth)
 
# Custom x axis
plt.xticks(r, names)
plt.xlabel("group")
 
# Show graphic
plt.show()

# %%
for i in range(len(df)):
    df.iloc[i,:] = round(df.iloc[i,:]*100.0/df.sum(axis=1)[i],0)
df
# Out:
#    greenBars  orangeBars  blueBars
# 0       74.0        19.0       7.0
# 1        5.0        48.0      48.0
# 2       23.0        17.0      60.0
# 3       40.0        40.0      20.0
# 4       17.0        50.0      33.0

# %%
r = range(5)
plt.bar(r,df['greenBars'],width = 0.5, color = '#b5ffb9',edgecolor ='white',label='Group A')
plt.bar(r,df['orangeBars'],bottom=df['greenBars'], color ='#f9bc86', width = 0.5, edgecolor='white',label='Group B')

plt.bar(r,df['blueBars'],bottom=[i+j for i,j in zip(df['greenBars'],df['orangeBars'])], color ='#a3acff', width = 0.5, edgecolor='white',label='Group C')
plt.legend(loc = 'upper left',bbox_to_anchor =(1,1),ncol=1)

plt.xticks(r,list('abcde'),fontsize=12)
for i,j in enumerate(df['orangeBars']):
    plt.text(i,df['greenBars'][i]+j/2, j, ha='center',va='center')

# %% [markdown]
# ### Diverging Bars with text

# %%
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mtcars.csv")
x = df.loc[:, ['mpg']]
df['mpg_z'] = (x - x.mean())/x.std()
df['colors'] = ['red' if x < 0 else 'green' for x in df['mpg_z']]
df.sort_values('mpg_z', inplace=True)
df.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(10,10), dpi= 80)
plt.hlines(y=df.index, xmin=0, xmax=df.mpg_z)
for x, y, tex in zip(df.mpg_z, df.index, df.mpg_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'red' if x < 0 else 'green', 'size':14})

# Decorations    
plt.yticks(df.index, df.cars, fontsize=12)
plt.title('Diverging Text Bars of Car Mileage', fontdict={'size':20})
style.use('seaborn-paper')
plt.xlim(-2.5, 2.5)
plt.show()

# %% [markdown]
# ### Area plot [parameters of annotation()](https://matplotlib.org/3.3.3/tutorials/text/annotations.html)

# %%
import numpy as np
import pandas as pd

# Prepare Data
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/economics.csv", parse_dates=['date']).head(100)
x = np.arange(df.shape[0])
y_returns = (df.psavert.diff().fillna(0)/df.psavert.shift(1)).fillna(0) * 100
## plot 
plt.figure(figsize=(10,8))

fcol = ['green' if y>=0 else 'red' for y in y_returns[1:]]
plt.fill_between(x[1:],y_returns[1:],0,where=y_returns[1:]>=0, facecolor='green',interpolate=True,alpha=0.7)
plt.fill_between(x[1:],y_returns[1:],0, where = y_returns[1:]<=0,facecolor = 'red',interpolate=True,alpha=0.7)

## annotate
plt.annotate("Peak",xy=(94.0,21.0),xytext=(85,28),bbox=dict(boxstyle='Round4',fc='firebrick'),arrowprops=dict(facecolor='steelblue',shrink=0.15),fontsize=15,color='white')
plt.text(25,20,'Sample Area plot',bbox=dict(boxstyle='Square',fc='grey',alpha=0.5),fontsize=15,ha='center')


## Decoration:
xtickvals = [str(m)[:3].upper()+'-'+str(y) for y,m in zip(df.date.dt.year,df.date.dt.month)]
## show date in a half-year base
plt.gca().set_xticks(x[::6])
plt.gca().set_xticklabels(xtickvals[::6],rotation=45,ha='center',va='center')
plt.ylim(-25,25)
# Out:
# (-25, 25)

# %%
plt.bar(x[1:],y_returns[1:],color=fcol)
# Out:
# <BarContainer object of 99 artists>

# %% [markdown]
# ### Ordered Bar Chart --- show ranking

# %%
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df_plot = df_raw.groupby('class').agg({'hwy':'mean'})
df_plot.sort_values(by='hwy',inplace=True)
df_plot.reset_index(inplace=True)
fig,ax=plt.subplots(figsize=(8,6),facecolor='white')
import matplotlib.cm as cm
style.use('seaborn-paper')
sns.barplot(x=df_plot.index,y=df_plot.hwy,palette='rocket',ax=ax)
ax.set_xticks(range(7))
ax.set_xticklabels(df_plot['class'],fontsize=10)
ax.set_yticklabels(ax.get_yticks(),fontsize=10,rotation=60,horizontalalignment='center')
ax.set_ylabel('hwy',fontsize=14)
ax.set_ylim((0,35))
ax.axhline(y=max(df_plot.hwy),linestyle='dashed',color='red')
for i,hwy in enumerate(df_plot.hwy):
    ax.text(i,hwy+0.5,round(hwy,0),horizontalalignment='center',bbox=dict(boxstyle='square',facecolor='grey',alpha=0.3),ha='center')
    
ax.set_title('Bar Chart for hwy',fontdict={'size':12})
#ax.set(xlabel='hwy',ylim = (0,35))

## Add patches to color X axis labels
import matplotlib.patches as patches
p1 = patches.Rectangle((0.57,-.005),width=0.33,height=0.13,alpha=0.2,facecolor='green',transform=fig.transFigure)
p2 = patches.Rectangle((0.124,-0.005),width=0.446,height=0.13,alpha=0.2,facecolor='red',transform=fig.transFigure)

fig.add_artist(p1)
fig.add_artist(p2)

# %% [markdown]
# ### Slope chart, comparing before and after for given sectors

# %%
df = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/gdppercap.csv")
## create left and right label
left_label = [str(c)+','+str(round(y)) for c,y in zip(df.continent,df['1952'])]
right_label = [str(c)+','+str(round(y)) for c,y in zip(df.continent,df['1957'])]
col = ['red' if df.loc[i,'1952']>df.loc[i,'1957'] else 'green' for i in range(len(df))]

fig,ax=plt.subplots(figsize=(10,8))
# vertical line
ax.vlines(x=1,ymin=500,ymax=13000,color = 'black',alpha=0.7,linewidth=1,linestyle='dotted')
ax.vlines(x=3,ymin=500,ymax=13000,color = 'black',alpha=0.7,linewidth=1,linestyle ='dotted')
ax.scatter(x=np.repeat(1,df.shape[0]),y=df['1952'],s=10,color='grey')
ax.scatter(x=np.repeat(3,df.shape[0]),y=df['1957'],s=10,color='grey')
for i,j in enumerate(df['1952']):
    if df.loc[i,'1952']<=df.loc[i,'1957']:
        ax.plot([1,3],[df['1952'][i],df['1957'][i]],'-',color='green')
    else:
        ax.plot([1,3],[df['1952'][i],df['1957'][i]],'-',color='red')
    # annotate
    ax.text(1-0.05,df['1952'][i],left_label[i],fontsize=12,horizontalalignment='right',verticalalignment='center')
    ax.text(3+0.05,df['1957'][i],left_label[i],fontsize=12,horizontalalignment='left',verticalalignment='center')
#ax.plot([1,3],[df['1952'][0],df['1957'][0]],'-',color='green')
ax.text(1-0.05,13000,'Before',fontsize=14,weight=700,horizontalalignment='right',verticalalignment='center')
ax.text(3+0.05,13000,'After',fontsize=14,weight=700,horizontalalignment='left',verticalalignment='center')
## set y,x labels
ax.set(xlim=(0,4), ylim=(0,14000), ylabel='Mean GDP Per Capita')
plt.yticks(range(0,14000,2000),fontsize=12)
ax.set_xticks([1,3])
ax.set_xticklabels(['1952','1957'],fontsize='14',weight='bold')
ax.grid('white')

plt.gca().spines["top"].set_alpha(.0)
plt.gca().spines["bottom"].set_alpha(.0)
plt.gca().spines["right"].set_alpha(.0)
plt.gca().spines["left"].set_alpha(.0)
plt.show()

# %% [markdown]
# ### Dumbbell plot

# %%
import matplotlib.lines as mlines
df = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/health.csv")
df.sort_values('pct_2014',inplace=True)
df.reset_index(inplace=True)

fig,ax=plt.subplots(1,1,figsize=(10,10),facecolor='#f7f7f7',dpi = 80)

#vertical lines
for i,v in enumerate([0.05,0.1,0.15,0.2,0.25]):
    ax.vlines(x=v,ymin =0,ymax=26, color='black',alpha=0.8,linewidth=1,linestyle='dotted')
    
#lines
for i,j in enumerate(df['pct_2013']):
    ax.scatter(y=df['index'][i],x=j,s=50,color='#0e668b',alpha=0.7)
    ax.scatter(y=df['index'][i],x=df['pct_2014'][i],s=50,color='#a3c4dc',alpha=1)
    #ax.plot([df['pct_2013'][i],df['pct_2014'][i]],[df['index'][i],df['index'][i]],'o-',color='#a3c4dc')
    l = mlines.Line2D([j,df['pct_2014'][i]], [df['index'][i],df['index'][i]], color='skyblue')
    ax.add_line(l)

ax.set_facecolor('#f7f7f7')
ax.set_title('xxx')
ax.set(xlim=(0,0.25),ylim=(-1,26),ylabel='Mean')
ax.set_xticks([0.05,0.1,0.15,0.2,0.25])
ax.set_xticklabels(['5%','10%','15%','20%','25%'],fontsize=12)
ax.set_xlabel('mean',fontsize=12)
ax.set_ylabel('index',fontsize=12)
ax.set_yticks(range(-1,26,3))
ax.set_yticklabels(range(-1,26,3),fontsize=12)
# Out:
# [Text(0, 0, '-1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '5'),
#  Text(0, 0, '8'),
#  Text(0, 0, '11'),
#  Text(0, 0, '14'),
#  Text(0, 0, '17'),
#  Text(0, 0, '20'),
#  Text(0, 0, '23')]

# %% [markdown]
# ### Time series with peaks and troughs annotated

# %%
df = pd.read_csv('https://github.com/selva86/datasets/raw/master/AirPassengers.csv')
df['newdt']=df.date.apply(lambda x: x[:4]+'-'+x[5:7])

# %%
df = pd.read_csv('https://github.com/selva86/datasets/raw/master/AirPassengers.csv')
df['newdt']=df.date.apply(lambda x: x[:4]+'-'+x[5:7])
# Get the Peaks and Troughs
data = df['value'].values
doublediff = np.diff(np.sign(np.diff(data)))
peak_locations = np.where(doublediff == -2)[0] + 1

doublediff2 = np.diff(np.sign(np.diff(-1*data)))
trough_locations = np.where(doublediff2 == -2)[0] + 1

# Draw Plot
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('date', 'value', data=df, color='tab:blue', label='Air Traffic')
plt.scatter(df.date[peak_locations], df.value[peak_locations], marker=mpl.markers.CARETUPBASE, color='tab:green', s=100, label='Peaks')
plt.scatter(df.date[trough_locations], df.value[trough_locations], marker=mpl.markers.CARETDOWNBASE, color='tab:red', s=100, label='Troughs')

# Annotate
for t, p in zip(trough_locations[1::5], peak_locations[::3]):
    plt.text(df.date[p], df.value[p]+15, df.date[p], horizontalalignment='center', color='darkgreen')
    plt.text(df.date[t], df.value[t]-35, df.date[t], horizontalalignment='center', color='darkred')

# Decoration
plt.ylim(50,750)
xtick_location = df.index.tolist()[::6]
xtick_labels = df.date.tolist()[::6]
plt.xticks(ticks=xtick_location, labels=xtick_labels, rotation=90, fontsize=12, alpha=.7)
plt.title("Peak and Troughs of Air Passengers Traffic (1949 - 1969)", fontsize=22)
plt.yticks(fontsize=12, alpha=.7)

# Lighten borders
plt.gca().spines["top"].set_alpha(.0)
plt.gca().spines["bottom"].set_alpha(.3)
plt.gca().spines["right"].set_alpha(.0)
plt.gca().spines["left"].set_alpha(.3)

plt.legend(loc='upper left')
plt.grid(axis='y', alpha=.3)
plt.show()

# %%
df = pd.read_csv('https://github.com/selva86/datasets/raw/master/mortality.csv')

# Define the upper limit, lower limit, interval of Y axis and colors
y_LL = 100
y_UL = int(df.iloc[:, 1:].max().max()*1.1)
y_interval = 400
mycolors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']    

# Draw Plot and Annotate
fig, ax = plt.subplots(1,1,figsize=(16, 9), dpi= 80)    

columns = df.columns[1:]  
for i, column in enumerate(columns):    
    plt.plot(df.date.values, df[column].values, lw=1.5, color=mycolors[i])    
    plt.text(df.shape[0]+1, df[column].values[-1], column, fontsize=14, color=mycolors[i])

# Draw Tick lines  
for y in range(y_LL, y_UL, y_interval):    
    plt.hlines(y, xmin=0, xmax=71, colors='black', alpha=0.3, linestyles="--", lw=0.5)

# Decorations    
plt.tick_params(axis="both", which="both", bottom=False, top=False,    
                labelbottom=True, left=False, right=False, labelleft=True)        

# Lighten borders
plt.gca().spines["top"].set_alpha(.3)
plt.gca().spines["bottom"].set_alpha(.3)
plt.gca().spines["right"].set_alpha(.3)
plt.gca().spines["left"].set_alpha(.3)

plt.title('Number of Deaths from Lung Diseases in the UK (1974-1979)', fontsize=22)
plt.yticks(range(y_LL, y_UL, y_interval), [str(y) for y in range(y_LL, y_UL, y_interval)], fontsize=12)    
plt.xticks(range(0, df.shape[0], 12), df.date.values[::12], horizontalalignment='left', fontsize=12)    
plt.ylim(y_LL, y_UL)    
plt.xlim(-2, 80)    
plt.show()
